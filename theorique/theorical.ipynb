# %%
import osmnx as ox
import matplotlib.pyplot as plt

place = 'Saint-Egreve,France'
graph = ox.graph_from_place(place)

# Plot the streets
fig, ax = ox.plot_graph(graph)

# Retrieve nodes and edges
nodes, edges = ox.graph_to_gdfs(graph)
print(nodes)
nodes.head()

# Plot the nodes
fig, ax = plt.subplots(figsize=(12,8))
nodes.plot(ax=ax, facecolor='black')
# Out:
#                     y         x  street_count            highway  ref  \
# osmid
# 124670      45.215722  5.680482             3                NaN  NaN
# 124680      45.239063  5.660960             3                NaN  NaN
# 136568      45.216096  5.682794             3                NaN  NaN
# 136648      45.218497  5.675163             3  motorway_junction  NaN
# 136650      45.218864  5.679504             3                NaN  NaN
# ...               ...       ...           ...                ...  ...
# 9397341920  45.243510  5.675388             3                NaN  NaN
# 9415526152  45.242496  5.666561             1                NaN  NaN
# 9415526159  45.242534  5.663971             3                NaN  NaN
# 9415526165  45.243119  5.663511             3                NaN  NaN
# 9415526166  45.242579  5.664089             4           crossing  NaN
#
#                             geometry
# osmid
# 124670      POINT (5.68048 45.21572)
# 124680      POINT (5.66096 45.23906)
# 136568      POINT (5.68279 45.21610)
# 136648      POINT (5.67516 45.21850)
# 136650      POINT (5.67950 45.21886)
# ...                              ...
# 9397341920  POINT (5.67539 45.24351)
# 9415526152  POINT (5.66656 45.24250)
# 9415526159  POINT (5.66397 45.24253)
# 9415526165  POINT (5.66351 45.24312)
# 9415526166  POINT (5.66409 45.24258)
#
# [3097 rows x 6 columns]
# <AxesSubplot:>
