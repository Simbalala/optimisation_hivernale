# %%
from graph import Graph
from chinese_postman import *
import osmnx as ox
import matplotlib.pyplot as plt

graph = ox.graph_from_place('Anjou, Montréal, QC, Canada', network_type='drive')

# Plot the streets
fig, ax = ox.plot_graph(graph)

# Retrieve nodes and edges
nodes, edges = ox.graph_to_gdfs(graph)
print(nodes)
nodes.head()

# Plot the nodes
fig, ax = plt.subplots(figsize=(12,8))
nodes.plot(ax=ax, facecolor='black')
# Out:
#                     y          x  street_count  ref highway  \
# osmid
# 17052729    45.599587 -73.571090             4  NaN     NaN
# 110468317   45.614176 -73.558358             3  NaN     NaN
# 224886238   45.623472 -73.584082             3  NaN     NaN
# 224911443   45.616856 -73.593841             4  NaN     NaN
# 224911467   45.613776 -73.599000             4  NaN     NaN
# ...               ...        ...           ...  ...     ...
# 8894840995  45.612685 -73.555094             3  NaN     NaN
# 8894841012  45.612401 -73.555184             4  NaN     NaN
# 8928577798  45.597144 -73.570585             3  NaN     NaN
# 9201323748  45.605662 -73.584283             3  NaN     NaN
# 9246558971  45.603063 -73.571807             2  NaN     NaN
#
#                               geometry
# osmid
# 17052729    POINT (-73.57109 45.59959)
# 110468317   POINT (-73.55836 45.61418)
# 224886238   POINT (-73.58408 45.62347)
# 224911443   POINT (-73.59384 45.61686)
# 224911467   POINT (-73.59900 45.61378)
# ...                                ...
# 8894840995  POINT (-73.55509 45.61269)
# 8894841012  POINT (-73.55518 45.61240)
# 8928577798  POINT (-73.57059 45.59714)
# 9201323748  POINT (-73.58428 45.60566)
# 9246558971  POINT (-73.57181 45.60306)
#
# [728 rows x 6 columns]
# <AxesSubplot:>
